# %%
# Project 1: My Data World Map
## Following is each part in a dedicated Markdown cell with a short associated explanation

# %%
# Part 1 
##print statement that outputs a meaningful statement
print("Hello there, my name is Theophilus. I generate data with around seven apps a day mainly")
# Out:
# Hello there, my name is Theophilus. I generate data with around seven apps a day mainly

# %%
# Part 2 
##list of apps used daily
daily_apps = ["Instagram", "Tiktok", "Youtube", "Microsoft Excel", "Google Chrome"]

# %%
# Part 3 
##dictionary mapping each app to the data type
app_descr = ["Photos and videos", "Short form content", "Music and long form videos", "Spreadsheets and financial data", "General knowledge"]
my_dict = dict(zip(daily_apps, app_descr))
print(my_dict)
# Out:
# {'Instagram': 'Photos and videos', 'Tiktok': 'Short form content', 'Youtube': 'Music and long form videos', 'Microsoft Excel': 'Spreadsheets and financial data', 'Google Chrome': 'General knowledge'}

# %%
# Part 4 
##for loop that iterates and prints each item
for key,val in my_dict.items():
    print (key,":", val)
# Out:
# Instagram : Photos and videos
# Tiktok : Short form content
# Youtube : Music and long form videos
# Microsoft Excel : Spreadsheets and financial data
# Google Chrome : General knowledge
